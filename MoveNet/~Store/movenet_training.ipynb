# %%
import itertools
import numpy as np
import os
import pandas as pd
import tempfile
import tqdm
import sys

from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import tensorflow as tf
from tensorflow import keras

# Load MoveNet Thunder model
from script.data import BodyPart
from script.ml import Movenet

# %%
# Define function to run pose estimation using MoveNet Thunder.  You'll apply MoveNet's cropping algorithm and run inference
# multiple times on the input image to improve pose estimation accuracy.
move_net = Movenet('./model/movenet_thunder')
def detect(input_tensor, inference_count=3, per=None):
  # Detect pose using the full input image
  move_net.detect(input_tensor.numpy(), reset_crop_region=True)
  # Repeatedly using previous detection result to identify the region of interest and only cropping that region to improve
  # detection accuracy
  for _ in range(inference_count - 1):
    per = move_net.detect(input_tensor.numpy(), reset_crop_region=False)

  return per

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
  """Calculates the center point of the two given landmarks."""
  left = tf.gather(landmarks, left_bodypart.value, axis=1)
  right = tf.gather(landmarks, right_bodypart.value, axis=1)
  return left * 0.5 + right * 0.5

def get_pose_size(landmarks, torso_size_multiplier=2.5):
  # Hips center
  hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP, BodyPart.RIGHT_HIP)
  # Shoulders center
  shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER, BodyPart.RIGHT_SHOULDER)
  # Torso size as the minimum body size
  torso_size = tf.linalg.norm(shoulders_center - hips_center)
  # Pose center
  pose_center_new = tf.expand_dims(get_center_point(landmarks, BodyPart.LEFT_HIP, BodyPart.RIGHT_HIP), axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform substraction
  pose_center_new = tf.broadcast_to(pose_center_new, [tf.size(landmarks) // (17*2), 17, 2])
  # Dist to pose center
  d = tf.gather(landmarks - pose_center_new, 0, axis=0, name="dist_to_pose_center")
  # Normalize scale                                                   Max dist to pose center
  return tf.maximum(torso_size * torso_size_multiplier, tf.reduce_max(tf.linalg.norm(d, axis=0)))

def normalize_pose_landmarks(landmarks):
  # Move landmarks so that the pose center becomes (0,0)
  pose_center = tf.expand_dims(get_center_point(landmarks, BodyPart.LEFT_HIP, BodyPart.RIGHT_HIP), axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform substraction
  pose_center = tf.broadcast_to(pose_center, [tf.size(landmarks) // (17*2), 17, 2])
  landmarks = landmarks - pose_center
  # Scale the landmarks to a constant pose size
  return landmarks / get_pose_size(landmarks)

def landmarks_to_embedding(landmarks_and_scores):
  """Converts the input landmarks into a pose embedding."""
  # Reshape the flat input into a matrix with shape=(17, 3)
  reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)
  # Normalize landmarks 2D Flatten the normalized landmark coordinates into a vector
  return keras.layers.Flatten()(normalize_pose_landmarks(reshaped_inputs[:, :, :2]))

# %%
from sklearn.model_selection import train_test_split

class MoveNetClassifier(object):
    def __init__(self, class_names):
        self.model = None
        self.class_names = class_names

    def build_model(self, model_path=None):
        if model_path:
            self.model = keras.models.load_model(model_path)
        else:
            inputs = keras.Input(shape=(51))
            embedding = landmarks_to_embedding(inputs)

            layer = keras.layers.Dense(128, activation=tf.nn.relu6)(embedding)
            layer = keras.layers.Dropout(0.5)(layer)
            layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
            layer = keras.layers.Dropout(0.5)(layer)
            outputs = keras.layers.Dense(len(self.class_names), activation="softmax")(layer)

            model = keras.Model(inputs, outputs)
            model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

            self.model = model

    def train(self, X_data, y_data, test_size=0.15, monitor="val_accuracy", patience=20, batch_size=16, epochs=200,
              cp_path="best.weight.hdf5", save_path=None):
        # Split training data (X, y) into (X_train, y_train) and (X_val, y_val)
        X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, test_size=test_size)
        # Add a checkpoint callback to store the checkpoint that has the highest validation accuracy.
        checkpoint = keras.callbacks.ModelCheckpoint(cp_path, monitor=monitor, verbose=1, save_best_only=True, mode='max')
        early_stopping = keras.callbacks.EarlyStopping(monitor=monitor, patience=patience)
        # Start training
        his = self.model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs,
                                 callbacks=[checkpoint, early_stopping], validation_data=(X_val, y_val))
        if save_path:
            self.model.save(save_path)
        return his

    def evaluate(self, X, y):
        return self.model.evaluate(X, y)

    def predict(self, X):
        return self.model.predict(X)

    def save_tflite(self, save_path):
        converter = tf.lite.TFLiteConverter.from_keras_model(self.model)
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        model = converter.convert()

        with open(f'{save_path}/pose_classifier.tflite', 'wb') as f:
          f.write(model)
        print('Model size: %dKB' % (len(model) / 1024))

# %%
def load_pose_landmarks(csv_path):
  # Load the CSV file
  dataframe = pd.read_csv(csv_path)
  # Extract the list of class names
  filename = dataframe.pop('file_name').unique()
  # Extract the labels
  y = keras.utils.to_categorical(dataframe.pop('class_no'))
  # Convert the input features and labels into the correct format for training.
  X = dataframe.astype('float64')
  return filename, X, y

# %%
import csv

class MoveNetMark(object):
  """Helper class to preprocess pose sample images for classification."""
  def __init__(self, images_in_folder, csvs_out_path):
    self._images_in_folder = images_in_folder
    self._csvs_out_path = csvs_out_path

  def process(self, per_pose_class_limit=None, detection_threshold=0.1):
    # Create a temp dir to store the pose CSVs per class
    temp_folder = tempfile.mkdtemp()
    # Get list of pose classes and print image statistics
    class_names = sorted([n for n in os.listdir(self._images_in_folder) if not n.startswith('.')])
    # Loop through the classes and preprocess its images
    messages = []
    for pose_class_name in class_names:
      print('Preprocessing', pose_class_name, file=sys.stderr)
      # Paths for the pose class.
      images_in_folder = os.path.join(self._images_in_folder, pose_class_name)
      # Detect landmarks in each image and write it to a CSV file
      with open(os.path.join(temp_folder, pose_class_name + '.csv'), 'w') as csv_out_file:
        csv_out_writer = csv.writer(csv_out_file, delimiter=',', quoting=csv.QUOTE_MINIMAL)
        # Get list of images
        image_names = sorted([n for n in os.listdir(images_in_folder) if not n.startswith('.')])
        if per_pose_class_limit is not None:
          image_names = image_names[:per_pose_class_limit]
        # Detect pose landmarks from each image
        valid_image_count = 0
        for image_name in tqdm.tqdm(image_names):
          image_path = os.path.join(images_in_folder, image_name)
          try:
            image = tf.io.decode_jpeg(tf.io.read_file(image_path))
            _, _, channel = image.shape
          except:
            messages.append('Skipped ' + image_path + '. Invalid image.')
            continue
          # Skip images that isn't RGB because Movenet requires RGB images
          if channel != 3:
            messages.append('Skipped ' + image_path + '. Image isn\'t in RGB format.')
            continue
          person = detect(image)
          # Save landmarks if all landmarks were detected
          if not min([keypoint.score for keypoint in person.keypoints]) >= detection_threshold:
            messages.append('Skipped ' + image_path + '. No pose was confidentlly detected.')
            continue
          # Get landmarks and scale it to the same size as the input image
          pose_landmarks = np.array( [[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                                      for keypoint in person.keypoints], dtype=np.float32)
          # Write the landmark coordinates to its per-class CSV file
          csv_out_writer.writerow([image_name] + pose_landmarks.flatten().astype(np.str).tolist())
          valid_image_count += 1
        if not valid_image_count:
          raise RuntimeError('No valid images found for the "{}" class.'.format(pose_class_name))
    # Print the error message collected during preprocessing.
    print('\n'.join(messages))
    # Combine all per-class CSVs into a single output file
    total_df = None
    for class_index, class_name in enumerate(class_names):
      per_class_df = pd.read_csv(os.path.join(temp_folder, class_name + '.csv'), header=None)
      # Add the labels
      per_class_df['class_no'] = [class_index]*len(per_class_df)
      per_class_df['class_name'] = [class_name]*len(per_class_df)
      total_df = per_class_df if total_df is None else pd.concat([total_df, per_class_df], axis=0)
    list_name = [[bodypart.name + '_x', bodypart.name + '_y', bodypart.name + '_score'] for bodypart in BodyPart]
    header_name = ['file_name']
    for columns_name in list_name:
      header_name += columns_name
    total_df.rename({total_df.columns[i]: header_name[i] for i in range(len(header_name))}, axis=1, inplace=True)
    total_df.to_csv(self._csvs_out_path, index=False)

# %%
class MoveNetPreprocessor(object):
  """Helper class to preprocess pose sample images for classification."""

  def __init__(self, images_in_folder, csvs_out_path):
    self._images_in_folder = images_in_folder
    self._csvs_out_path = csvs_out_path
    self._messages = []

    # Create a temp dir to store the pose CSVs per class
    self._csvs_out_folder_per_class = tempfile.mkdtemp()

    # Get list of pose classes and print image statistics
    self._pose_class_names = sorted([n for n in os.listdir(self._images_in_folder) if not n.startswith('.')])

  def process(self, per_pose_class_limit=None, detection_threshold=0.1):
    # Loop through the classes and preprocess its images
    for pose_class_name in self._pose_class_names:
      print('Preprocessing', pose_class_name, file=sys.stderr)

      # Paths for the pose class.
      images_in_folder = os.path.join(self._images_in_folder, pose_class_name)
      csv_out_path = os.path.join(self._csvs_out_folder_per_class, pose_class_name + '.csv')

      # Detect landmarks in each image and write it to a CSV file
      with open(csv_out_path, 'w') as csv_out_file:
        csv_out_writer = csv.writer(csv_out_file, delimiter=',', quoting=csv.QUOTE_MINIMAL)
        # Get list of images
        image_names = sorted([n for n in os.listdir(images_in_folder) if not n.startswith('.')])
        if per_pose_class_limit is not None:
          image_names = image_names[:per_pose_class_limit]

        valid_image_count = 0

        # Detect pose landmarks from each image
        for image_name in tqdm.tqdm(image_names):
          image_path = os.path.join(images_in_folder, image_name)

          try:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
          except:
            self._messages.append('Skipped ' + image_path + '. Invalid image.')
            continue
          else:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
            image_height, image_width, channel = image.shape

          # Skip images that isn't RGB because Movenet requires RGB images
          if channel != 3:
            self._messages.append('Skipped ' + image_path + '. Image isn\'t in RGB format.')
            continue
          person = detect(image)

          # Save landmarks if all landmarks were detected
          min_landmark_score = min(
              [keypoint.score for keypoint in person.keypoints])
          should_keep_image = min_landmark_score >= detection_threshold
          if not should_keep_image:
            self._messages.append('Skipped ' + image_path + '. No pose was confidentlly detected.')
            continue

          valid_image_count += 1

          # Get landmarks and scale it to the same size as the input image
          pose_landmarks = np.array([[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                                    for keypoint in person.keypoints], dtype=np.float32)

          # Write the landmark coordinates to its per-class CSV file
          coordinates = pose_landmarks.flatten().astype(np.str).tolist()
          csv_out_writer.writerow([image_name] + coordinates)

        if not valid_image_count:
          raise RuntimeError('No valid images found for the "{}" class.'.format(pose_class_name))

    # Print the error message collected during preprocessing.
    print('\n'.join(self._messages))

    # Combine all per-class CSVs into a single output file
    all_landmarks_df = self._all_landmarks_as_dataframe()
    all_landmarks_df.to_csv(self._csvs_out_path, index=False)

  def class_names(self):
    """List of classes found in the training dataset."""
    return self._pose_class_names

  def _all_landmarks_as_dataframe(self):
    """Merge all per-class CSVs into a single dataframe."""
    total_df = None
    for class_index, class_name in enumerate(self._pose_class_names):
      csv_out_path = os.path.join(self._csvs_out_folder_per_class, class_name + '.csv')
      per_class_df = pd.read_csv(csv_out_path, header=None)

      # Add the labels
      per_class_df['class_no'] = [class_index]*len(per_class_df)
      per_class_df['class_name'] = [class_name]*len(per_class_df)

      # Append the folder name to the filename column (first column)
      per_class_df[per_class_df.columns[0]] = (os.path.join(class_name, '') + per_class_df[per_class_df.columns[0]].astype(str))

      if total_df is None:
        # For the first class, assign its data to the total dataframe
        total_df = per_class_df
      else:
        # Concatenate each class's data into the total dataframe
        total_df = pd.concat([total_df, per_class_df], axis=0)

    list_name = [[bodypart.name + '_x', bodypart.name + '_y', bodypart.name + '_score'] for bodypart in BodyPart]
    header_name = ['file_name']
    for columns_name in list_name:
      header_name += columns_name
    header_map = {total_df.columns[i]: header_name[i] for i in range(len(header_name))}

    total_df.rename(header_map, axis=1, inplace=True)

    return total_df

# %%
with open(f'./pose_labels.txt', 'r') as csv_out_file:
  class_names = list(csv_out_file)

images_ROOT = "./data/yoga_poses/"
images_in_train_folder = os.path.join(images_ROOT, 'train')
images_in_test_folder = os.path.join(images_ROOT, 'test')

csvs_out_train_path = tempfile.mkdtemp() + "train_data.csv"
csvs_out_test_path = tempfile.mkdtemp() + "test_data.csv"

# movenetmark = MoveNetMark(images_in_folder=images_in_train_folder, csvs_out_path=csvs_out_train_path)
# movenetmark.process()
# movenetmark = MoveNetMark(images_in_folder=images_in_test_folder, csvs_out_path=csvs_out_test_path)
# movenetmark.process()
movenetmark = MoveNetPreprocessor(images_in_folder=images_in_train_folder, csvs_out_path=csvs_out_train_path)
movenetmark.process()
movenetmark = MoveNetPreprocessor(images_in_folder=images_in_test_folder, csvs_out_path=csvs_out_test_path)
movenetmark.process()
# Out:
# Preprocessing chair
#   0%|          | 0/200 [00:00<?, ?it/s]D:\Compiler\Software_ENV\Conda\envs\Mod_UseEnviron\lib\site-packages\ipykernel_launcher.py:70: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 100%|██████████| 200/200 [00:12<00:00, 16.29it/s]
# Preprocessing cobra
# 100%|██████████| 200/200 [00:12<00:00, 16.31it/s]
# Preprocessing dog
# 100%|██████████| 200/200 [00:12<00:00, 16.33it/s]
# Preprocessing tree
# 100%|██████████| 200/200 [00:12<00:00, 16.45it/s]
# Preprocessing warrior
# 100%|██████████| 200/200 [00:12<00:00, 16.41it/s]
# Preprocessing chair
# Skipped ./data/yoga_poses/train\chair\girl3_chair091.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair092.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair093.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair094.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair096.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair097.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair099.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair100.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair104.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair106.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair110.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair114.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair115.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair118.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair122.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair123.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair124.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair125.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair131.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair132.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair133.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair134.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair136.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair138.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair139.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\girl3_chair142.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\guy2_chair089.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\guy2_chair136.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\guy2_chair140.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\guy2_chair143.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\guy2_chair144.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\guy2_chair145.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\chair\guy2_chair146.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra026.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra029.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra030.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra038.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra040.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra041.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra048.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra050.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra051.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra055.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra059.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra061.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra068.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra070.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra081.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra087.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra088.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra089.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra090.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra091.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra092.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra093.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra094.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra096.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra099.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra102.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra110.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra112.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra115.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra119.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra122.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra128.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra129.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra136.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl1_cobra140.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl2_cobra029.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl2_cobra046.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl2_cobra050.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl2_cobra053.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl2_cobra108.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl2_cobra117.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl2_cobra129.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl2_cobra133.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl2_cobra136.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl2_cobra140.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra028.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra030.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra032.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra039.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra040.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra051.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra052.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra058.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra062.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra068.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra072.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra076.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra078.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra079.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra082.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra088.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra092.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra097.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra099.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra107.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra129.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra130.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra132.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra134.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\girl3_cobra138.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra034.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra042.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra043.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra047.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra053.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra065.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra077.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra078.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra080.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra081.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra084.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra088.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra089.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra102.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra105.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra108.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\cobra\guy2_cobra139.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl1_dog027.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl1_dog028.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl1_dog030.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl1_dog032.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog075.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog080.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog083.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog085.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog087.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog088.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog090.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog091.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog093.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog094.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog095.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog099.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog100.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog101.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog103.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog104.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog105.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog107.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl2_dog111.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog025.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog026.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog027.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog028.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog031.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog033.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog035.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog037.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog040.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog041.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog047.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog052.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog062.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog072.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog074.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog075.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog077.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog081.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog082.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog086.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog088.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog090.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog092.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog094.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog095.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog096.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog100.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog102.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog103.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog104.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog106.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog107.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\girl3_dog111.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\guy1_dog070.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\guy1_dog076.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\guy2_dog070.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\guy2_dog071.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\dog\guy2_dog082.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\girl2_tree119.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\girl2_tree122.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\girl2_tree161.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\girl2_tree163.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy1_tree139.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy1_tree140.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy1_tree141.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy1_tree143.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy2_tree085.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy2_tree086.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy2_tree087.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy2_tree088.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy2_tree090.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy2_tree092.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy2_tree145.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\tree\guy2_tree147.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior049.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior053.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior064.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior066.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior067.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior072.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior075.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior077.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior080.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior083.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior084.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior087.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior089.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior093.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior094.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior095.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior098.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior099.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior100.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior103.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior108.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior109.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior111.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior112.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior113.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior114.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior116.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl1_warrior117.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior047.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior049.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior050.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior052.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior057.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior058.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior063.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior068.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior079.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior083.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior085.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior088.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior092.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior096.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior097.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior102.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior106.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl2_warrior108.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior042.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior043.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior047.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior049.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior051.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior054.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior056.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior057.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior061.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior066.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior067.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior073.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior074.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior075.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior079.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior087.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior089.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior090.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior091.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior092.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior094.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior095.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior096.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior100.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior103.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior107.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior115.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior117.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior134.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior140.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\girl3_warrior143.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior043.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior048.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior051.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior052.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior055.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior057.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior062.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior068.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior069.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior073.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior076.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior077.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior080.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior081.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior082.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior088.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior091.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior092.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior093.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior094.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior097.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior118.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior120.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior121.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior124.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior125.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior126.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior131.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior134.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior135.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior138.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior143.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior145.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy1_warrior148.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior051.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior086.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior111.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior118.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior122.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior129.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior131.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior135.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior137.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior139.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior145.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/train\warrior\guy2_warrior148.jpg. No pose was confidentlly detected.
# 100%|██████████| 84/84 [00:05<00:00, 16.36it/s]
# Preprocessing cobra
# 100%|██████████| 116/116 [00:07<00:00, 16.34it/s]
# Preprocessing dog
# 100%|██████████| 90/90 [00:05<00:00, 16.36it/s]
# Preprocessing tree
# 100%|██████████| 96/96 [00:05<00:00, 16.35it/s]
# Preprocessing warrior
# 100%|██████████| 109/109 [00:06<00:00, 16.39it/s]
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra048.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra050.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra051.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra052.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra053.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra054.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra055.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra056.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra057.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra058.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra059.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra060.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra062.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra069.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra075.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra077.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra081.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra124.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra131.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra132.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra134.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra135.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\cobra\guy3_cobra136.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\dog\guy3_dog025.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\dog\guy3_dog026.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\dog\guy3_dog036.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\dog\guy3_dog042.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\dog\guy3_dog106.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\dog\guy3_dog108.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior042.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior043.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior044.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior045.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior046.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior047.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior048.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior050.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior051.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior052.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior053.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior054.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior055.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior056.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior059.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior060.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior062.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior063.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior065.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior066.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior068.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior070.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior071.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior072.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior073.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior074.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior075.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior076.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior077.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior079.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior080.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior081.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior082.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior083.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior084.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior085.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior086.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior087.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior088.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior089.jpg. No pose was confidentlly detected.
# Skipped ./data/yoga_poses/test\warrior\guy3_warrior137.jpg. No pose was confidentlly detected.

# %%
# Load the data
_, X, y = load_pose_landmarks(csvs_out_train_path)
# Load the test data
_, X_test, y_test = load_pose_landmarks(csvs_out_test_path)

classifier = MoveNetClassifier(class_names)
classifier.build_model()
# Start training
history = classifier.train(X, y, cp_path="./model/weights.best.hdf5", save_path="./model/classifier/")
# Evaluate the model using the TEST dataset
loss, accuracy = classifier.evaluate(X_test, y_test)

# %%
# Visualize the training history to see whether you're overfitting.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'VAL'], loc='lower right')
plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
  """Plots the confusion matrix."""
  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalized confusion matrix")
  else:
    print('Confusion matrix, without normalization')

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=55)
  plt.yticks(tick_marks, classes)
  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.tight_layout()

# Classify pose in the TEST dataset using the trained model
y_pred = classifier.predict(X_test)

# Convert the prediction result to class name
y_pred_label = [class_names[i] for i in np.argmax(y_pred, axis=1)]
y_true_label = [class_names[i] for i in np.argmax(y_test, axis=1)]

# Plot the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
plot_confusion_matrix(cm, class_names, title ='Confusion Matrix of Pose Classification Model')

# Print the classification report
print('\nClassification Report:\n', classification_report(y_true_label, y_pred_label))

# %%
classifier.save_tflite("./model/")
